# %%
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
df_train = pd.read_csv('train.tsv', sep = '\t', header=None)

df_train.info()
df_train.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 101 entries, 0 to 100
# dtypes: float64(101)
# memory usage: 7.7 MB
#             0             1             2         3             4         5    \
# 0  5.081360e-03  2.732210e-03  3.976420e-03  0.004540  4.731020e-03  0.005066
# 1  4.174910e-03  7.084480e-03  2.123510e-03  0.000003  3.681860e-03  0.004573
# 2  1.175410e-03  1.298870e-03  2.000290e-03  0.004009  3.330520e-03  0.004482
# 3  5.845890e-03  5.368910e-03  6.507510e-03  0.006121  8.502420e-03  0.008948
# 4  5.600000e-07  3.700000e-07  6.200000e-07  0.000002  9.700000e-07  0.000002
#
#         6         7         8             9    ...       91            92   \
# 0  0.002552  0.003555  0.003674  4.089900e-03  ...  0.005197  1.644370e-03
# 1  0.003550  0.008086  0.006227  3.793680e-03  ...  0.000264  5.655750e-03
# 2  0.000404  0.000320  0.000136  3.351720e-03  ...  0.003521  3.148270e-03
# ...

# %%
import numpy as np

X_train = df_train.values[:, :100]
y_train = df_train.values[:, 100] 

def predict(X, w):
    return X @ w

def mean_squared_error(y_pred, y_true):
    return np.mean((y_true - y_pred)**2)

def LinearRegression(X_train, y_train, epochs=10000, alpha=100):
    N = X_train.shape[0]
    weights = np.random.randn(100)
    
    for epoch in range(epochs):
        y_pred = predict(X_train, weights)
        error = y_pred - y_train
        
        gradient = 2 * X_train.T @ error / N
        
        weights -= alpha * gradient
        
        if epoch % 10 == 0:
            mse = mean_squared_error(y_pred, y_train)
            print(f"Epoch {epoch}, MSE: {mse:.9f}")
    
    return weights

# %%
weights = LinearRegression(X_train, y_train)
# Out:
# Epoch 0, MSE: 0.322678139
# Epoch 10, MSE: 0.001005581
# Epoch 20, MSE: 0.000961378
# Epoch 30, MSE: 0.000919158
# Epoch 40, MSE: 0.000878832
# Epoch 50, MSE: 0.000840311
# Epoch 60, MSE: 0.000803514
# Epoch 70, MSE: 0.000768362
# Epoch 80, MSE: 0.000734780
# Epoch 90, MSE: 0.000702697
# Epoch 100, MSE: 0.000672043
# Epoch 110, MSE: 0.000642755
# Epoch 120, MSE: 0.000614771
# Epoch 130, MSE: 0.000588030
# Epoch 140, MSE: 0.000562477
# Epoch 150, MSE: 0.000538057
# Epoch 160, MSE: 0.000514721
# Epoch 170, MSE: 0.000492417
# Epoch 180, MSE: 0.000471101
# Epoch 190, MSE: 0.000450727
# Epoch 200, MSE: 0.000431253
# Epoch 210, MSE: 0.000412637
# Epoch 220, MSE: 0.000394843
# Epoch 230, MSE: 0.000377832
# Epoch 240, MSE: 0.000361569
# Epoch 250, MSE: 0.000346022
# Epoch 260, MSE: 0.000331157
# Epoch 270, MSE: 0.000316944
# Epoch 280, MSE: 0.000303354
# Epoch 290, MSE: 0.000290360
# Epoch 300, MSE: 0.000277933
# Epoch 310, MSE: 0.000266050
# Epoch 320, MSE: 0.000254686
# ...

# %%
df_test = pd.read_csv('test.tsv', sep = '\t', header=None)

df_test.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.001625  0.001477  0.002368  0.004169  0.002668  0.002014  0.001802
# 1  0.004432  0.003121  0.003630  0.003058  0.000837  0.001640  0.001846
# 2  0.005194  0.004270  0.002174  0.000443  0.005398  0.001527  0.000288
# 3  0.014504  0.017867  0.002476  0.004764  0.008116  0.016214  0.011130
# 4  0.000413  0.000121  0.000385  0.000338  0.000413  0.000190  0.000306
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.001962  0.003036  0.004454  ...  0.001312  0.001178  0.003841  0.003548
# 1  0.001204  0.004186  0.003113  ...  0.001787  0.001105  0.000442  0.004347
# 2  0.004906  0.005213  0.005860  ...  0.005762  0.000901  0.004286  0.006097
# 3  0.009624  0.011102  0.006736  ...  0.002136  0.014053  0.004479  0.003603
# 4  0.000034  0.000008  0.000124  ...  0.000353  0.000333  0.000290  0.000031
#
#          94        95        96        97        98        99
# ...

# %%
answers = df_test.values @ weights

# %%
answers = pd.DataFrame(answers)
answers.to_csv('answers.tsv', sep='\t', header=None, index=None)
